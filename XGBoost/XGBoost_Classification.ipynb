# %% [markdown]
# <a href="https://colab.research.google.com/github/varunbommagunta/TreeModels/blob/main/XGBoost/XGBoost_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score,roc_auc_score,make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix,plot_confusion_matrix

# %%
df = pd.read_csv('/content/Telco_customer_churn.csv')

# %%
df.head()
# Out:
#    CustomerID  Count  ...  CLTV                   Churn Reason
# 0  3668-QPYBK      1  ...  3239   Competitor made better offer
# 1  9237-HQITU      1  ...  2701                          Moved
# 2  9305-CDSKC      1  ...  5372                          Moved
# 3  7892-POOKP      1  ...  5003                          Moved
# 4  0280-XJGEX      1  ...  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.drop(['Churn Label','Churn Score','CLTV','Churn Reason'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    CustomerID  Count        Country  ... Monthly Charges Total Charges  Churn Value
# 0  3668-QPYBK      1  United States  ...           53.85        108.15            1
# 1  9237-HQITU      1  United States  ...           70.70        151.65            1
# 2  9305-CDSKC      1  United States  ...           99.65         820.5            1
# 3  7892-POOKP      1  United States  ...          104.80       3046.05            1
# 4  0280-XJGEX      1  United States  ...          103.70        5036.3            1
#
# [5 rows x 29 columns]

# %%
df['Count'].unique()
# Out:
# array([1])

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['California'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Los Angeles', 'Beverly Hills', 'Huntington Park', ..., 'Standish',
#        'Tulelake', 'Olympic Valley'], dtype=object)

# %%
df.drop(['CustomerID','Count','Country','State','Lat Long'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#           City  Zip Code   Latitude  ...  Monthly Charges Total Charges Churn Value
# 0  Los Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df['City'].replace(' ','_',regex = True,inplace = True)
df.head()
# Out:
#           City  Zip Code   Latitude  ...  Monthly Charges Total Charges Churn Value
# 0  Los_Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los_Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los_Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los_Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los_Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df['City'].unique()[:10]
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', 'Lynwood',
#        'Marina_Del_Rey', 'Inglewood', 'Santa_Monica', 'Torrance',
#        'Whittier', 'La_Habra'], dtype=object)

# %%
df.columns = df.columns.str.replace(' ','_')
df.head()
# Out:
#           City  Zip_Code   Latitude  ...  Monthly_Charges Total_Charges Churn_Value
# 0  Los_Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los_Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los_Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los_Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los_Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df['Phone_Service'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.isna().sum()
# Out:
# City                 0
# Zip_Code             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# Churn_Value          0
# dtype: int64

# %%
df['Total_Charges'].unique()
# Out:
# array(['108.15', '151.65', '820.5', ..., '7362.9', '346.45', '6844.5'],
#       dtype=object)

# %%
len(df.loc[df['Total_Charges'] == ' '])
# Out:
# 11

# %%
df.loc[df['Total_Charges']== ' ']
# Out:
#                 City  Zip_Code  ...  Total_Charges  Churn_Value
# 2234  San_Bernardino     92408  ...                           0
# 2438    Independence     93526  ...                           0
# 2568       San_Mateo     94401  ...                           0
# 2667       Cupertino     95014  ...                           0
# 2856        Redcrest     95569  ...                           0
# 4331     Los_Angeles     90029  ...                           0
# 4687        Sun_City     92585  ...                           0
# 5104      Ben_Lomond     95005  ...                           0
# 5719        La_Verne     91750  ...                           0
# 6772            Bell     90201  ...                           0
# 6840      Wilmington     90744  ...                           0
#
# [11 rows x 24 columns]

# %%
df.loc[(df['Total_Charges']==' '),'Total_Charges'] = 0

# %%
df.loc[df['Tenure_Months'] == 0]
# Out:
#                 City  Zip_Code  ...  Total_Charges  Churn_Value
# 2234  San_Bernardino     92408  ...              0            0
# 2438    Independence     93526  ...              0            0
# 2568       San_Mateo     94401  ...              0            0
# 2667       Cupertino     95014  ...              0            0
# 2856        Redcrest     95569  ...              0            0
# 4331     Los_Angeles     90029  ...              0            0
# 4687        Sun_City     92585  ...              0            0
# 5104      Ben_Lomond     95005  ...              0            0
# 5719        La_Verne     91750  ...              0            0
# 6772            Bell     90201  ...              0            0
# 6840      Wilmington     90744  ...              0            0
#
# [11 rows x 24 columns]

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %%
df.replace(' ','_',regex = True,inplace = True)
df.head()
# Out:
#           City  Zip_Code  ...  Total_Charges  Churn_Value
# 0  Los_Angeles     90003  ...         108.15            1
# 1  Los_Angeles     90005  ...         151.65            1
# 2  Los_Angeles     90006  ...         820.50            1
# 3  Los_Angeles     90010  ...        3046.05            1
# 4  Los_Angeles     90015  ...        5036.30            1
#
# [5 rows x 24 columns]

# %%
df.isna().sum()
# Out:
# City                 0
# Zip_Code             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# Churn_Value          0
# dtype: int64

# %%
X = df.drop('Churn_Value',axis = 1).copy()
X.head()
# Out:
#           City  Zip_Code  ...  Monthly_Charges  Total_Charges
# 0  Los_Angeles     90003  ...            53.85         108.15
# 1  Los_Angeles     90005  ...            70.70         151.65
# 2  Los_Angeles     90006  ...            99.65         820.50
# 3  Los_Angeles     90010  ...           104.80        3046.05
# 4  Los_Angeles     90015  ...           103.70        5036.30
#
# [5 rows x 23 columns]

# %%
y = df['Churn_Value'].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %%
X_encoded = pd.get_dummies(X,columns = ['City','Gender','Senior_Citizen','Partner','Dependents','Phone_Service','Multiple_Lines','Internet_Service','Online_Security','Online_Backup','Device_Protection','Tech_Support','Streaming_TV','Streaming_Movies','Contract','Paperless_Billing','Payment_Method'])

# %%
X_encoded.head()
# Out:
#    Zip_Code  ...  Payment_Method_Mailed_check
# 0     90003  ...                            1
# 1     90005  ...                            0
# 2     90006  ...                            0
# 3     90010  ...                            0
# 4     90015  ...                            0
#
# [5 rows x 1178 columns]

# %%
y.unique()
# Out:
# array([1, 0])

# %%
y.shape
# Out:
# (7043,)

# %%
X_encoded.shape
# Out:
# (7043, 1178)

# %%
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %%
X_train,X_test,y_train,y_test = train_test_split(X_encoded,y,random_state = 42)

# %%
sum(y_train)/len(y_train)
# Out:
# 0.2593714502082545

# %%
sum(y_test)/len(y_test)
# Out:
# 0.2833617262918796

# %%
clf = xgb.XGBClassifier(objective = 'binary:logistic',n_estimators = 142)
clf.fit(X_train,y_train,verbose = True,early_stopping_rounds = 16,eval_metric = 'aucpr',eval_set = [(X_test,y_test)])
# Out:
# [0]	validation_0-aucpr:0.606126
# Will train until validation_0-aucpr hasn't improved in 16 rounds.
# [1]	validation_0-aucpr:0.61548
# [2]	validation_0-aucpr:0.651429
# [3]	validation_0-aucpr:0.649413
# [4]	validation_0-aucpr:0.654058
# [5]	validation_0-aucpr:0.660678
# [6]	validation_0-aucpr:0.660407
# [7]	validation_0-aucpr:0.661594
# [8]	validation_0-aucpr:0.661719
# [9]	validation_0-aucpr:0.66582
# [10]	validation_0-aucpr:0.679101
# [11]	validation_0-aucpr:0.680797
# [12]	validation_0-aucpr:0.683092
# [13]	validation_0-aucpr:0.683204
# [14]	validation_0-aucpr:0.684754
# [15]	validation_0-aucpr:0.687346
# [16]	validation_0-aucpr:0.688245
# [17]	validation_0-aucpr:0.69077
# [18]	validation_0-aucpr:0.691213
# [19]	validation_0-aucpr:0.692434
# [20]	validation_0-aucpr:0.693138
# [21]	validation_0-aucpr:0.697024
# [22]	validation_0-aucpr:0.699323
# [23]	validation_0-aucpr:0.70008
# [24]	validation_0-aucpr:0.700038
# [25]	validation_0-aucpr:0.701199
# [26]	validation_0-aucpr:0.70176
# ...

# %%
plot_confusion_matrix(clf,X_test,y_test,values_format = 'd',display_labels = ["Did not leave","Left"])

# %%
from sklearn.metrics import classification_report

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1262
#            1       0.69      0.56      0.62       499
#
#     accuracy                           0.80      1761
#    macro avg       0.76      0.73      0.74      1761
# weighted avg       0.80      0.80      0.80      1761
